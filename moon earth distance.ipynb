# %%
## In this program I will show the distance from the Earth to the Earth's moon at different times of the year. 

import math 
from pylab import plot, xlabel, ylabel, show, legend, xlim, ylim, title, annotate  #Used for plotting
import datetime # Used to create the days and print them
from math import sin, cos, radians, pi ## for easy of typing for plots


######### setup constants #######
G = 6.67e-11
Me = 5.97e24
Mm = 7.35e22
Fp = 2.2994965322261994e+20   ## Force at Perigee
Fa = 1.770715916065035e+20    ## force at apogee
######################################################################

################ Here is how you add the time aspect ##################
year = 2019 #chosen year
# create date objects
day1 = datetime.date(year, 1, 1)
day365 = datetime.date(year, 12, 31)
one_day = datetime.timedelta(days=1)
next_day = day1
days = []  #empty list to be filled 
for day in range(0, 366):  # includes potential leap year
    if next_day > day365:
        break
    days.append(next_day)
    #if next_day.weekday() == 4 and next_day.day == 13:
    #    print (next_day)
    # increment date object by one day
    next_day += one_day

#print (days[3])
####################################################################


######### User inputs for values needed #############################
day_enter = int(input("Enter the day of the year(0-364): "))
if day_enter > 364 or day_enter < 0:
    print("Out of range, please choose another number: ")
    day_enter = int(input("Enter the day of the year(0-364): "))
    if day_enter > 364 or day_enter < 0:
        print("Out of range, please choose another number: ")
        day_enter = int(input("Enter the day of the year(0-364): "))
        if day_enter > 364 or day_enter < 0:
            print("Out of range, please choose another number: ")
            day_enter = int(input("Enter the day of the year(0-364): "))
            if day_enter > 364 or day_enter < 0:
                print("Out of range, please choose another number: ")
                day_enter = int(input("Enter the day of the year(0-364): "))
                if day_enter > 364 or day_enter < 0:
                    print("Out of range, please choose another number(last attempt before termination of program): ")
                    day_enter = int(input("Enter the day of the year(0-364): "))
   
    
##########################################################################################################

######### Setup of picking the day and its corresponding force to be used in equation ##################
if days[day_enter] in {days[7], days[35], days[62], days[89], days[117], days[145], days[173], \
                       days[200], days[228], days[255], days[282], days[310], days[337]}:
    F = Fa
    theta = 0 

elif days[day_enter] in {days[20], days[49], days[77], days[105], days[132], days[157], days[185],\
                       days[213],  days[241], days[269], days[298], days[326], days[351]}:
    F = Fp
    theta = 180

elif days[day_enter] < days[7]:
    x = (Fp - Fa)/(8) ## increment for each day 
    y = 1
    k = 8
    theta = 200
    for k in range(0,6):
        if days[day_enter] != days[k]:
            y+=1
            theta += 24
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[7] and days[day_enter] < days[20]:
    x = (Fp - Fa)/(20-7) ## increment for each day
    y = 1
    k = 8
    theta = 13.8
    for k in range(8,19):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12.5
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)

elif days[day_enter] > days[20] and days[day_enter] < days[35]:
    x = (Fp - Fa)/(35-20) ## increment for each day 
    y = 1
    k = 21
    theta = 192
    for k in range(21,34):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[35] and days[day_enter] < days[49]:
    x = (Fp - Fa)/(49-35) ## increment for each day 
    y = 1
    k = 36
    theta = 13
    for k in range(36,48):
        if days[day_enter] != days[k]:
            y+=1
            theta +=12.5
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)

elif days[day_enter] > days[49] and days[day_enter] < days[62]:
    x = (Fp - Fa)/(62-49) ## increment for each day 
    y = 1
    k = 50
    theta = 194
    for k in range(50,61):
        if days[day_enter] != days[k]:
            y+=1
            theta += 13.5
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[62] and days[day_enter] < days[77]:
    x = (Fp - Fa)/(77-62) ## increment for each day
    y = 1
    k = 63
    theta = 12
    for k in range(63,76):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)    

elif days[day_enter] > days[77] and days[day_enter] < days[89]:
    x = (Fp - Fa)/(89-77) ## increment for each day
    y = 1
    k = 78
    theta = 195
    for k in range(78,88):
        if days[day_enter] != days[k]:
            y+=1
            theta += 15
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[89] and days[day_enter] < days[105]:
    x = (Fp - Fa)/(105-89) ## increment for each day 
    y = 1
    k = 90
    theta = 11
    for k in range(90,104):
        if days[day_enter] != days[k]:
            y+=1
            theta += 11
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)    

elif days[day_enter] > days[105] and days[day_enter] < days[117]:
    x = (Fp - Fa)/(117-105) ## increment for each day 
    y = 1
    k = 106
    theta = 195
    for k in range(106,116):
        if days[day_enter] != days[k]:
            y+=1
            theta += 15
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[117] and days[day_enter] < days[132]:
    x = (Fp - Fa)/(132-118) ## increment for each day
    y = 1
    k = 118
    theta = 12.5
    for k in range(118,131):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12.5
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)  

elif days[day_enter] > days[132] and days[day_enter] < days[145]:
    x = (Fp - Fa)/(145-132) ## increment for each day
    y = 1
    k = 133
    theta = 194
    for k in range(133,144):
        if days[day_enter] != days[k]:
            y+=1
            theta += 14
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[145] and days[day_enter] < days[157]:
    x = (Fp - Fa)/(157-145) ## increment for each day 
    y = 1
    k = 146
    theta = 15
    for k in range(146,156):
        if days[day_enter] != days[k]:
            y+=1
            theta += 15
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)  

elif days[day_enter] > days[157] and days[day_enter] < days[173]:
    x = (Fp - Fa)/(173-157) ## increment for each day 
    y = 1
    k = 158
    theta = 191
    for k in range(158,172):
        if days[day_enter] != days[k]:
            y+=1
            theta += 11
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[173] and days[day_enter] < days[185]:
    x = (Fp - Fa)/(185-173) ## increment for each day 
    y = 1
    k = 174
    theta = 15
    for k in range(174,184):
        if days[day_enter] != days[k]:
            y+=1
            theta += 15
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)  

elif days[day_enter] > days[185] and days[day_enter] < days[200]:
    x = (Fp - Fa)/(200-185) ## increment for each day
    y = 1
    k = 186
    theta = 192
    for k in range(186,199):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[200] and days[day_enter] < days[213]:
    x = (Fp - Fa)/(213-200) ## increment for each day 
    y = 1
    k = 201
    theta = 13.5
    for k in range(201,212):
        if days[day_enter] != days[k]:
            y+=1
            theta += 13.5
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)  

elif days[day_enter] > days[213] and days[day_enter] < days[228]:
    x = (Fp - Fa)/(228-213) ## increment for each day 
    y = 1
    k = 214
    theta = 192
    for k in range(214,227):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)
    
elif days[day_enter] > days[228] and days[day_enter] < days[241]:
    x = (Fp - Fa)/(241-228) ## increment for each day 
    y = 1
    k = 229
    theta = 13.5
    for k in range(229,240):
        if days[day_enter] != days[k]:
            y+=1
            theta += 13.5
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y)  

elif days[day_enter] > days[241] and days[day_enter] < days[255]:
    x = (Fp - Fa)/(255-241) ## increment for each day 
    y = 1
    k = 242
    theta = 192.5
    for k in range(242,254):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12.5
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[255] and days[day_enter] < days[269]:
    x = (Fp - Fa)/(269-255) ## increment for each day 
    y = 1
    k = 256
    theta = 12.5
    for k in range(256,268):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12.5
        if days[day_enter] == days[k]:
            break   
    F = Fa + (x*y) 

elif days[day_enter] > days[269] and days[day_enter] < days[282]:
    x = (Fp - Fa)/(282-269) ## increment for each day 
    y = 1
    k = 270
    theta = 193.5
    for k in range(270,281):
        if days[day_enter] != days[k]:
            y+=1
            theta += 13.5
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[282] and days[day_enter] < days[298]:
    x = (Fp - Fa)/(298-282) ## increment for each day 
    y = 1
    k = 283
    theta = 11
    for k in range(283,297):
        if days[day_enter] != days[k]:
            y+=1
            theta += 11
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y) 

elif days[day_enter] > days[298] and days[day_enter] < days[310]:
    x = (Fp - Fa)/(310-298) ## increment for each day 
    y = 1
    k = 299
    theta = 195
    for k in range(299,310):
        if days[day_enter] != days[k]:
            y+=1
            theta += 15
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[310] and days[day_enter] < days[326]:
    x = (Fp - Fa)/(326-310) ## increment for each day 
    y = 1
    k = 311
    theta = 11
    for k in range(311,325):
        if days[day_enter] != days[k]:
            y+=1
            theta += 11
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y) 

elif days[day_enter] > days[326] and days[day_enter] < days[337]:
    x = (Fp - Fa)/(337-326) ## increment for each day 
    y = 1
    k = 327
    theta = 196
    for k in range(327,336):
        if days[day_enter] != days[k]:
            y+=1
            theta += 16
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)

elif days[day_enter] > days[337] and days[day_enter] < days[351]:
    x = (Fp - Fa)/(351-337) ## increment for each day 
    y = 1
    k = 338
    theta = 12.5
    for k in range(338,350):
        if days[day_enter] != days[k]:
            y+=1
            theta += 12.5
        if days[day_enter] == days[k]:
            break
    F = Fa + (x*y) 

elif days[day_enter] < days[364]:
    x = (Fp - Fa)/(13) ## increment for each day 
    y = 1
    k = 352
    theta = 193.5
    for k in range(352,363):
        if days[day_enter] != days[k]:
            y+=1
            theta += 13.5
        if days[day_enter] == days[k]:
            break
    F = Fp - (x*y)
    
####################################################################
r = math.sqrt((G*Me*Mm)/F)
r_km = r/1000
a_float = 3.14159
formatted_r_km= "{:.2f}".format(r_km)
#F = (G*Me*Mm)/(r**2)


print ("The distance from the moon to the Earth is:", formatted_r_km, "kilometers on,",days[day_enter],'.')
print ("The force of gravity between the moon and Earth at this time is approximately: ", F, "Newtons.")
############## Prints either if the moon is atapogee of perigee #####################################
if days[day_enter] in {days[7], days[35], days[62], days[89], days[117], days[145], days[173], \
                       days[200], days[228], days[255], days[282], days[310], days[337]}:
    print ("The moon is at Apogee today, so tides are high and moon looks small.")
elif days[day_enter] in {days[20], days[49], days[77], days[105], days[132], days[157], days[185],\
                       days[213],  days[241], days[269], days[298], days[326], days[351]}:
    print ("The moon is at Perigee today, so tides are low and moon looks large.")    
else:
    print ("The moon is NOT at Apogee or Perigee today.")
    
print ("The angle is:",theta, " degrees.")     ### Accuaracy to the nearest whole degree
####################### Plotting code starts here ######################################################
print ("The plot representation is below.")
moony = sin(radians(theta)) * r_km
moonx = cos(radians(theta)) * r_km

title("Distance from Earth to moon")
xlabel("Distance in kilometers")
ylabel("Distance in kilometers")
xlim(-450000,450000)
ylim(-450000,450000)
distance_label = formatted_r_km
annotate(days[day_enter], (moonx, moony), textcoords="offset points", xytext=(0,15),ha='center')
pEarth, = plot(0,0,'go',markersize=50, label='handletextpad=0.8') 
pMoon, = plot(moonx,moony, 'ko', markersize=13.6, markeredgewidth=0)
distance, = plot([0,moonx], [0,moony], "b-")
legend ([pEarth, pMoon, distance], ["Earth", "Moon", str(distance_label) + " km"],bbox_to_anchor=(1.05, 1), \
        borderpad=2.5,labelspacing=6, handletextpad = 2.5,  loc='upper left', borderaxespad=0.)

##############################################################################################################
# Out:
# Enter the day of the year(0-364):  269
# The distance from the moon to the Earth is: 356761.00 kilometers on, 2019-09-27 .
# The force of gravity between the moon and Earth at this time is approximately:  2.2994965322261994e+20 Newtons.
# The moon is at Perigee today, so tides are low and moon looks large.
# The angle is: 180  degrees.
# The plot representation is below.
